# %%
print("2+3", end='=')
print(2+3)
# Out:
# 2+3=5

# %%
print("Hi", "Hi", sep='...', end='...')
print('Hi')
# Out:
# Hi...Hi...Hi

# %%
print("'It's Hero Time!'\n\t\t- Ben 10")
# Out:
# 'It's Hero Time!'
# 		- Ben 10

# %%
name = 'Ramu'
crop = 'Rice'
Yield = 50
print(Yield)
# Out:
# 50

# %%
#String Indexing value use to print the letter
name, balance = "Siva", 200
print(type(name))
print(type(balance))
print(name[3])
# Out:
# <class 'str'>
# <class 'int'>
# a

# %%
a = 10
b = 5
c = 3
print(a+b*c)
# Out:
# 25

# %%
print(20-10/5*2)
# Out:
# 16.0

# %%
round (7.243367364,2)
print(2%10)
# Out:
# 2

# %%
print(2%10)
# Out:
# 2

# %%
print(2**3**(2%10))
# Out:
# 512

# %%
a = "Siva"
b = "siva"

print(a==b)
print(a<b)
# Out:
# False
# True

# %%
name, balance = "Siva", 500.0
percentage = 7
balance = (percentage/100) * 500.0
balance = balance + 500.0
print(balance)
# Out:
# 535.0

# %%
#Before Swapping
a = 5
b = 7
print(a, b)

#After Swapping
c = a
a = b
b = c
print(a, b)

#Swapping Technic
a, b = b, a
print(a, b)
# Out:
# 5 7
# 7 5
# 5 7

# %%
a = 5
b = 10

a += b
b = a - b
a -= b
print(a, b)
# Out:
# 10 5

# %%
#Membership operator
numbers = [1, 4, '2', 8, 5]

print(2 in numbers)
print(10 not in numbers)
# Out:
# False
# True

# %%
a = 'Spider'
b = 'spider'

print(a == b)
print(a > b)
print(a < b)

print("ASCHII Value of 'S' : ", ord('S'))
print("ASCHII Value of 's' : ", ord('s'))
# Out:
# False
# False
# True
# ASCHII Value of 'S' :  83
# ASCHII Value of 's' :  115

# %%
#Logical Operator
a = 10
b = 5

statement1 = (a==10)
statement2 = (b==10)

print("a value is : ", statement1)
print("b value is : ", statement2)

print("Using AND '&' Operator the value of a and b is : ", statement1 and statement2)
print("Using OR '|' Operator the value of a and b is  : ", statement1 or statement2)

print(not(False))
print(not(True))
# Out:
# a value is :  True
# b value is :  False
# Using AND '&' Operator the value of a and b is :  False
# Using OR '|' Operator the value of a and b is  :  True
# True
# False

# %%
num = 10
print(num > 5 and num < 15)
print(num % 2 == 0 or num % 3 == 0)
print(not (num == 0))
# Out:
# True
# True
# True

# %%
#Bitwise Operator
a = 2
b = 3
c = 7

print(a>>2)
print(c<<1)

x = 10
y = 4

print(x & y)
print(x | y)
print(x ^ y)
# Out:
# 0
# 14
# 0
# 14
# 14

# %%
#String Replication
a = "Bitcoin"

print(a * 100, end=" ")
# Out:
# ...

# %%
for i in range(1,10+1):
    print(i, a)
# Out:
# 1 Bitcoin
# 2 Bitcoin
# 3 Bitcoin
# 4 Bitcoin
# 5 Bitcoin
# 6 Bitcoin
# 7 Bitcoin
# 8 Bitcoin
# 9 Bitcoin
# 10 Bitcoin

# %%
#String Replication
Stars = "*"
greeting = "Happy" + " Coding!"

print(Stars*20, "\n", greeting, "\n\n",Stars*20)
# Out:
# ********************
#  Happy Coding!
#
#  ********************

# %%
coinName = input("Enter your block Chain name : ")

print(coinName*5)
# Out:
#  SolSolSolSolSol

# %%
a = int(input("Enter a value : "))
b = int(input("Enter b value : "))
c = int(input("Enter c value : "))

result = (a**3) + 2*b*c +(c**2)
print("The Result is : ",result)
# Out:
# The Result is :  471

# %%
#Unit Digit
num = input("Enter a value : ")
print(num[len(num)-1])

sen = '467'
print(len(sen))
# Out:
# 5
# 3

# %%
#unit Digit
arr = '1234'
arr[-1]
# Out:
# '4'

# %%
#unit Digit
unit = int(input("Enter a value : "))

unit %= 10
print(unit)
# Out:
# 7

# %%
number = 2 
match number: 
    case 1: print("One") 
    case 2 | 3: print("Two or Three") 
    case _: print("Other number")
