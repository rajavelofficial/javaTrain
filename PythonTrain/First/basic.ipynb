# %%
print("2+3", end='=')
print(2+3)
# Out:
# 2+3=5

# %%
print("Hi", "Hi", sep='...', end='...')
print('Hi')
# Out:
# Hi...Hi...Hi

# %%
print("'It's Hero Time!'\n\t\t- Ben 10")
# Out:
# 'It's Hero Time!'
# 		- Ben 10

# %%
name = 'Ramu'
crop = 'Rice'
Yield = 50
print(Yield)
# Out:
# 50

# %%
#String Indexing value use to print the letter
name, balance = "Siva", 200
print(type(name))
print(type(balance))
print(name[3])
# Out:
# <class 'str'>
# <class 'int'>
# a
