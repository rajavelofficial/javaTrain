# %%
age = int(input("Enter Your age : "))
if age >= 18:
    print("Your are eligible for Vote.")
else:
    print("Your not eligible for vote.")
# Out:
# Your not eligible for vote.

# %%
number = int(input("Enter the number : "))
if number > 0:
    print("The given number is postive")
# Out:
# The given number is postive

# %%
mark = int(input("Enter your mark : "))
if mark >= 40:
    print("Your Pass the exam.")
else:
    print("Your not Pass the Exam.")
# Out:
# Your Pass the exam.

# %%
accountBalance = float(input("Enter your account balance : "))
purchingPrice = float(input("Enter the purches Amount : "))

balance = accountBalance
purches = purchingPrice

if balance >= purches:
    print("Your Purching is Completed.")
else:
    print("You Cann't purches this Base Token, Because your account amount is very low.")
# Out:
# You Cann't purches this Base Token, Because your account amount is very low.

# %%
distance = float(input("Enter your distance in Kilometer : "))

if distance <= 2:
    print("You can walk.")
elif distance <= 10:
    print("You can take Byecycle or Scotter.")
elif distance <= 50:
    print("Taking the car or public Transport")
else:
    print("Consider Flight")
# Out:
# Consider Flight

# %%
beteryPower = int(input("Enter the Phone Battery Purcentage : "))

if beteryPower == 100:
    print("Phone Fully Charged.")
elif beteryPower <= 99 | beteryPower >= 51:
    print("Phone Power is ",  beteryPower)
elif beteryPower == 50:
    print("Half Charge only Availabe.")
elif beteryPower <= 49 | beteryPower >= 21:
    print("Phone Power is", beteryPower)
else:
    print("Low Percentage, Please Charge.")
# Out:
# Phone Power is  46

# %%
username = input("Enter username : ")

if username == "Admin":
    password = input("Enter Password : ")
    if password == "12345":
        print("Password is Correct, Login Sucessfully.")
    else:
        print("Password is Incorrect.")
else:
    print("Username Can't find.")
# Out:
# Password is Correct, Login Sucessfully.

# %%
num = int(input("Enter the number : "))
print("Even" if num % 2 == 0 else "odd")
# Out:
# odd

# %%
whetherCelsios = float(input("Enter whether rate : "))
print("Whether is Hot" if whetherCelsios > 32 else "Whether is Cool" )
# Out:
# Whether is Hot

# %%
grade = input("Enter the Grade Rate (A/B/C) : ").upper()

match grade:
    case 'A':
        print("Excellet")
    case 'B':
        print("Good")
    case 'C':
        print("Average")
    case _:
        print("Fail")
# Out:
# Excellet

# %%
# n = 5
# for num in range (-1, n):
#     print(num)

coin = ['Bitcoin', 'Solana', 'Base']
for coinlist in range (len(coin)):
    print(coin[coinlist])
# Out:
# Bitcoin
# Solana
# Base

# %%
count = 0
while(count < 3):
    count += 1
    print("Code fast")
# Out:
# Code fast
# Code fast
# Code fast

# %%
for i in range(1, 5):
    for j in range(i):
        print(i, end='  ')
    print()
# Out:
# 1
# 2  2
# 3  3  3
# 4  4  4  4

# %%
count = 0
while(count < 1):
    count += 1
    print(count)
    break
else:
    print("No Break")
# Out:
# 1

# %%
items = input("Enter shopping items separated by commas: ").split(',')

for item in items:
    clean_item = item.strip()
    if clean_item:  # Only prints if the string isn't empty
        print("Buy:", clean_item)
# Out:
# Buy: Tea
# Buy: Coffee
# Buy: Bread Omlet
# Buy: Snakcs

# %%
n = int(input("Enter a number: "))

for i in range(1, n + 1):
    print("Square of", i,"is", i**2)
# Out:
# Square of 1 is 1
# Square of 2 is 4
# Square of 3 is 9
# Square of 4 is 16
# Square of 5 is 25

# %%
# Out:
# 7
# 5
